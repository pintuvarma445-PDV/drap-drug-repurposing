# %%
import pandas as pd

df = pd.read_csv(r"D:\drap-drug-repurposing\data\sample_molecules.csv")
df.head()
# Out:
#                    smiles  activity
# 0     CCOC(=O)C1=CC=CC=C1       7.2
# 1   CCN(CC)CCOC1=CC=CC=C1       6.8
# 2  CCOC(=O)NCCC1=CC=CC=C1       7.5
# 3    CCOC(=O)C2=CC=CC=C2O       6.9
# 4  CCN(CC)CCOC2=CC=CC=C2O       7.0
